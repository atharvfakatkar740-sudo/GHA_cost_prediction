# %% [markdown]
# # Comprehensive EDA — GitHub Actions Workflow Duration Prediction
# ### Predicting `duration_minutes` from Workflow YAML & Codebase Features
#
# **Objective:** Thoroughly explore the dataset to understand feature distributions, relationships, and predictive relevance for `duration_minutes`.
#
# **Excluded Features (by design):**
#
# | Feature | Reason for Exclusion |
# |---|---|
# | `total_cost_usd` | Deterministic function of target — **data leakage** |
# | `workflow_name` | Free-text label — meaningless for unseen repos |
# | `repo_name` | Repository identifier, not a predictive feature |
# | `head_sha` | Commit hash identifier, not a predictive feature |
#
# **Table of Contents:**
# 1. Setup & Imports
# 2. Data Loading & Overview
# 3. Data Cleaning & Type Casting
# 4. Missing Values Analysis
# 5. Target Variable Deep Dive
# 6. Outlier Detection & Removal
# 7. Descriptive Statistics
# 8. Numeric Feature Distributions
# 9. Binary Feature Analysis
# 10. Categorical Feature Analysis
# 11. Feature–Target Correlations
# 12. Scatter Plots — Every Numeric Feature vs Target
# 13. Feature–Feature Correlation Heatmap
# 14. Multicollinearity (VIF) Analysis
# 15. Non-Linearity Diagnostics
# 16. Random Forest Feature Importance
# 17. Final Composite Feature Ranking
# 18. Overall EDA Summary & Recommendations
